# %%
import glob, os
import json
import json

#with open('parsed/US.AK/closed/5GN2-XGG1-DXDT-G4MK-00000-00.json', 'r') as f:
#     data = json.load(f)
#x = data["parties"][0]["charges"][0]["charge_description"]
#y = data["case_docket_label"]

# for root, dirs, files in os.walk("parsed/US.AK/closed"):
#     for file in files:
#         print(file)
#         data = json.load(file)
#         try:
#             print(data["parties"][0]["charges"][0]["charge_description"])
#         except:
#             continue
for dirs in os.walk("parsed"):  #/US.AK/closed
    k = dirs[1]
    print(k)
    print("ALL STATES +++++++++++++++++++++++++++")
    for i in k: ##states
        print("i*************",i)
        for  dirss in os.walk(str(i)): #current US.ss 
            print("dirss^^^^^^^^^",dirss)
            for root, dirs, files in os.walk("closed"):
                di = []
                for file in files:
                    with open(os.path.join(root,file),'r') as f:
                        data = json.load(f)

                    try:
                        charges = data["parties"][0]["charges"]

                        for d in charges:
                            if "charge_description" in d.keys():
                                for i,j in d.items():
                                    if i == "charge_description":
                                        di.append(j) 
                        # for i in data["parties"][0]["charges"]:
                        #     print(data["parties"][0]["charges"]['charge_description'])
                    except:
                        continue
                #print(di)
                charges = {i : di}
                with open('charges_description.json', 'w') as f:
                    json.dump(charges, f)
# Out:
# ['US.AK', 'US.ALM', 'US.ALN', 'US.ALS', 'US.ARE', 'US.ARW', 'US.AZ', 'US.CAC', 'US.CAE', 'US.CAN', 'US.CAS', 'US.CO', 'US.CT', 'US.DC', 'US.DE', 'US.FLM', 'US.FLN', 'US.FLS', 'US.GAM', 'US.GAN', 'US.GAS', 'US.GU', 'US.HI', 'US.IAN', 'US.IAS', 'US.ID', 'US.ILC', 'US.ILN', 'US.ILS', 'US.INN', 'US.INS', 'US.KS', 'US.KYE', 'US.KYW', 'US.LAE', 'US.LAM', 'US.LAW', 'US.MA', 'US.MD', 'US.ME', 'US.MIE', 'US.MIW', 'US.MN', 'US.MOE', 'US.MOW', 'US.MSN', 'US.MSS', 'US.MT', 'US.NCE', 'US.NCM', 'US.NCW', 'US.ND', 'US.NE', 'US.NH', 'US.NJ', 'US.NM', 'US.NMI', 'US.NV', 'US.NYE', 'US.NYN', 'US.NYS', 'US.NYW', 'US.OHN', 'US.OHS', 'US.OKE', 'US.OKN', 'US.OKW', 'US.OR', 'US.PAE', 'US.PAM', 'US.PAW', 'US.PR', 'US.RI', 'US.SC', 'US.SD', 'US.TNE', 'US.TNM', 'US.TNW', 'US.TXE', 'US.TXN', 'US.TXS', 'US.TXW', 'US.UT', 'US.VAE', 'US.VAW', 'US.VI', 'US.VT', 'US.WAE', 'US.WAW', 'US.WIE', 'US.WIW', 'US.WVN', 'US.WVS', 'US.WY']
# ALL STATES +++++++++++++++++++++++++++
# i************* US.AK
# ...

# %%
import pandas as pd
old = "qq"
l=[]
for root, dirs, files in os.walk("parsed/"): 
    for file in files:
        with open(os.path.join(root,file),'r') as f:
            data = json.load(f)
            cur_file_name = data["case_file_name"].split('.')[2].split('_')[0]
            print(cur_file_name,old)
            if  cur_file_name != old:
                print("change")
                charges = {old : l}
                #####
                #with open('charges_description.json') as feedsjson:
                #    feeds = json.load(feedsjson)
                #    feeds.append(charges)
                #with open('charges_description.json', mode='w') as f:
                #    f.write(json.dumps(feeds, indent=2))
                #######
                #with open('charges_description2.json', 'a') as f:
                    #cha = ','
                    #json.dump(cha, f)
                with open('charges_description3.json', 'a') as f:
                    json.dump(charges, f)
                with open('charges_description3.json', 'a') as f:
                    f.write(',')
                    
                l = []
                old = cur_file_name
            try:
                charges = data["parties"][0]["charges"]
                for i in charges:
                    # print(i)
                    for m, j in i.items():
                        if m == 'charge_description':
                            l.append(j)
            except:
                continue
            
        
#print(l)
# Out:
# AK qq
# change
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# ALM AK
# change
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ...

# %%
import re,json
with open('charges_description3.json','r') as f:
    datas = json.load(f)
    data = datas['final']
    for eachd in data:
        for i,j in eachd.items():
            l = []
            for itm in j:
                z = re.match("[0-9]*:[0-9]*", itm )
                if z:
                    l.append(z.group())
                num = {i : l}
            with open('charges_number1.json', 'a') as ff:
                    json.dump(num, ff)
            with open('charges_number1.json', 'a') as ff:
                    ff.write(',')

# %%
with open('charges_number1.json','r') as f:
    datas = json.load(f)
    data = datas['final']
    for i in data:
        for key,value in i.items():
            val = tuple(set(value))
        num = {key : val}
        with open('charges_number_unique.json', 'a') as ff:
                    json.dump(num, ff)
        with open('charges_number_unique.json', 'a') as ff:
                    ff.write(',')

# %%
import pandas as pd
old = "qq"
l=[]
for root, dirs, files in os.walk("parsed/"): 
    for file in files:
        with open(os.path.join(root,file),'r') as f:
            data = json.load(f)
            cur_file_name = data["case_file_name"].split('.')[2].split('_')[0]
            print(cur_file_name,old)
            if  cur_file_name != old:
                print("change")
                charges = {old : l}
                #####
                #with open('charges_description.json') as feedsjson:
                #    feeds = json.load(feedsjson)
                #    feeds.append(charges)
                #with open('charges_description.json', mode='w') as f:
                #    f.write(json.dumps(feeds, indent=2))
                #######
                #with open('charges_description2.json', 'a') as f:
                    #cha = ','
                    #json.dump(cha, f)
                with open('charges_disposition.json', 'a') as f:
                    json.dump(charges, f)
                with open('charges_disposition.json', 'a') as f:
                    f.write(',')
                    
                l = []
                old = cur_file_name
            try:
                charges = data["parties"][0]["charges"]
                for i in charges:
                    # print(i)
                    for m, j in i.items():
                        if m == 'charge_disposition':
                            l.append(j)
            except:
                continue
            
        
#print(l)
# Out:
# AK qq
# change
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# AK AK
# ALM AK
# change
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ALM ALM
# ...
